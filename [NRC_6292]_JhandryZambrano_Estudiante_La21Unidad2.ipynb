# %% [markdown]
# # LIMPIEZA DE DATOS
# ## Importacion de librerias y carga del dataset

# %%
'''Importacion de librerias'''
import pandas as pd
import numpy as np

# %%
'''Carga del dataset'''
df=pd.read_csv("data_act_01.csv", sep= ';', encoding='latin-1')
df
# Out:
#          CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0      160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1      160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2      160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3      160912801                Report  2016-03-31T00:00:00    17:38
# 4      160912811                   594  2016-03-31T00:00:00    17:42
# ...          ...                   ...                  ...      ...
# 10046  160964210      Well Being Check  2016-04-05T00:00:00    23:38
# 10047  160964216          Traffic Stop  2016-04-05T00:00:00    23:43
# 10048  160964227          Traffic Stop  2016-04-05T00:00:00    23:48
# 10049  160964229          Passing Call  2016-04-05T00:00:00    23:48
# 10050  160964249          Traffic Stop  2016-04-05T00:00:00    23:54
#
#               CallDateTime   Disposition                  Address  \
# 0      2016-03-30T18:42:00           REP  100 Block Of Chilton Av
# ...

# %% [markdown]
# ## Primer Error

# %%
'''Mediante el uso del método isnull verificamos las columnas de nuestro dataset que tienen valores nulos '''
df.isnull().sum()
# Out:
# CrimeId                      0
# OriginalCrimeTypeName        0
# OffenseDate                  0
# CallTime                     0
# CallDateTime                 0
# Disposition                  0
# Address                      0
# City                       321
# State                        3
# AgencyId                     0
# Range                    10051
# AddressType                  0
# dtype: int64

# %% [markdown]
# ### Solución

# %%
''' Reemplazo do de valores  por cero'''
df[['City', 'Range','State']] = df[['City', 'Range','State']].fillna(value=0)
'''Impresion de 20 datos para verificar si los cambios son efectuados'''
df.head(20)
# Out:
#       CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0   160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1   160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2   160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3   160912801                Report  2016-03-31T00:00:00    17:38
# 4   160912811                   594  2016-03-31T00:00:00    17:42
# 5   160913003                 Ref'd  2016-03-31T00:00:00    18:29
# 6   160913050    Homeless Complaint  2016-03-31T00:00:00    18:43
# 7   160913056    Homeless Complaint  2016-03-31T00:00:00    18:47
# 8   160913078  Agg Assault / Adw Dv  2016-03-31T00:00:00    18:52
# 9   160913103            Encampment  2016-03-31T00:00:00    18:57
# 10  160913118              Burglary  2016-03-31T00:00:00    18:59
# 11  160913148     Suspicious Person  2016-03-31T00:00:00    19:08
# 12  160913167                    Ip  2016-03-31T00:00:00    19:13
# ...

# %% [markdown]
# '''La suma de valores nulos es 0 es decir se efectuaron los cambios'''
# df.isnull().sum()

# %%
df.head()
# Out:
#      CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0  160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1  160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2  160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3  160912801                Report  2016-03-31T00:00:00    17:38
# 4  160912811                   594  2016-03-31T00:00:00    17:42
#
#           CallDateTime Disposition                  Address           City  \
# 0  2016-03-30T18:42:00         REP  100 Block Of Chilton Av  San Francisco
# 1  2016-03-31T15:31:00         GOA  2300 Block Of Market St  San Francisco
# 2  2016-03-31T16:49:00         GOA  2300 Block Of Market St  San Francisco
# 3  2016-03-31T17:38:00         GOA      500 Block Of 7th St  San Francisco
# 4  2016-03-31T17:42:00         REP       Beale St/bryant St  San Francisco
#
#   State AgencyId  Range      AddressType
# 0    CA        1    0.0  Premise Address
# ...

# %%
df.isnull().sum()
# Out:
# CrimeId                  0
# OriginalCrimeTypeName    0
# OffenseDate              0
# CallTime                 0
# CallDateTime             0
# Disposition              0
# Address                  0
# City                     0
# State                    0
# AgencyId                 0
# Range                    0
# AddressType              0
# dtype: int64

# %%
codigo=df['CrimeId']
crimen=df['OriginalCrimeTypeName']
fecha=df['OffenseDate']
hora=df['CallTime']
fecha_hora=df['CallDateTime']
disposicion=df['Disposition']
direccion=df['Address']
ciudad=df['City']
estado=df['State']
agencia=df['AgencyId']
rango=df['Range']
tipo_de_direccion=df['AddressType']

# %% [markdown]
# ## Segundo Error

# %%
df.head()
# Out:
#      CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0  160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1  160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2  160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3  160912801                Report  2016-03-31T00:00:00    17:38
# 4  160912811                   594  2016-03-31T00:00:00    17:42
#
#           CallDateTime Disposition                  Address           City  \
# 0  2016-03-30T18:42:00         REP  100 Block Of Chilton Av  San Francisco
# 1  2016-03-31T15:31:00         GOA  2300 Block Of Market St  San Francisco
# 2  2016-03-31T16:49:00         GOA  2300 Block Of Market St  San Francisco
# 3  2016-03-31T17:38:00         GOA      500 Block Of 7th St  San Francisco
# 4  2016-03-31T17:42:00         REP       Beale St/bryant St  San Francisco
#
#   State AgencyId  Range      AddressType
# 0    CA        1    0.0  Premise Address
# ...

# %%
'''Nos indica que solo existen valores numericos por ende la suma nos produce cero. 
Esto significa que tenemos una columna vacia por ende es necesario eliminarla'''
df['Range'].sum()
# Out:
# 0.0

# %% [markdown]
# ### Solución

# %%
'''Borrado de datos'''
del(df['Range'])

# %%
df.head()
# Out:
#      CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0  160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1  160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2  160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3  160912801                Report  2016-03-31T00:00:00    17:38
# 4  160912811                   594  2016-03-31T00:00:00    17:42
#
#           CallDateTime Disposition                  Address           City  \
# 0  2016-03-30T18:42:00         REP  100 Block Of Chilton Av  San Francisco
# 1  2016-03-31T15:31:00         GOA  2300 Block Of Market St  San Francisco
# 2  2016-03-31T16:49:00         GOA  2300 Block Of Market St  San Francisco
# 3  2016-03-31T17:38:00         GOA      500 Block Of 7th St  San Francisco
# 4  2016-03-31T17:42:00         REP       Beale St/bryant St  San Francisco
#
#   State AgencyId      AddressType
# 0    CA        1  Premise Address
# 1    CA        1  Premise Address
# ...

# %%
#caracteristicas =['CrimeId','OriginalCrimeTypeName','OffenseDate','CallTime','CallDateTime','Disposition','Address','City','State','AgencyId','Range','AddressType']
#df['CrimeId'].sum()

# %% [markdown]
# ## Tercer error

# %%
df.head()
# Out:
#      CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0  160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1  160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2  160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3  160912801                Report  2016-03-31T00:00:00    17:38
# 4  160912811                   594  2016-03-31T00:00:00    17:42
#
#           CallDateTime Disposition                  Address           City  \
# 0  2016-03-30T18:42:00         REP  100 Block Of Chilton Av  San Francisco
# 1  2016-03-31T15:31:00         GOA  2300 Block Of Market St  San Francisco
# 2  2016-03-31T16:49:00         GOA  2300 Block Of Market St  San Francisco
# 3  2016-03-31T17:38:00         GOA      500 Block Of 7th St  San Francisco
# 4  2016-03-31T17:42:00         REP       Beale St/bryant St  San Francisco
#
#   State AgencyId      AddressType
# 0    CA        1  Premise Address
# 1    CA        1  Premise Address
# ...

# %% [markdown]
# ### Solucion

# %%
df.head()
# Out:
#      CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0  160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1  160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2  160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3  160912801                Report  2016-03-31T00:00:00    17:38
# 4  160912811                   594  2016-03-31T00:00:00    17:42
#
#           CallDateTime Disposition                  Address           City  \
# 0  2016-03-30T18:42:00         REP  100 Block Of Chilton Av  San Francisco
# 1  2016-03-31T15:31:00         GOA  2300 Block Of Market St  San Francisco
# 2  2016-03-31T16:49:00         GOA  2300 Block Of Market St  San Francisco
# 3  2016-03-31T17:38:00         GOA      500 Block Of 7th St  San Francisco
# 4  2016-03-31T17:42:00         REP       Beale St/bryant St  San Francisco
#
#   State AgencyId      AddressType
# 0    CA        1  Premise Address
# 1    CA        1  Premise Address
# ...

# %%
df.head()
# Out:
#      CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0  160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1  160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2  160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3  160912801                Report  2016-03-31T00:00:00    17:38
# 4  160912811                   594  2016-03-31T00:00:00    17:42
#
#           CallDateTime Disposition                  Address           City  \
# 0  2016-03-30T18:42:00         REP  100 Block Of Chilton Av  San Francisco
# 1  2016-03-31T15:31:00         GOA  2300 Block Of Market St  San Francisco
# 2  2016-03-31T16:49:00         GOA  2300 Block Of Market St  San Francisco
# 3  2016-03-31T17:38:00         GOA      500 Block Of 7th St  San Francisco
# 4  2016-03-31T17:42:00         REP       Beale St/bryant St  San Francisco
#
#   State AgencyId      AddressType
# 0    CA        1  Premise Address
# 1    CA        1  Premise Address
# ...

# %% [markdown]
# ## Cuarto Error

# %%
'''Reemplazo de los valores nulos de la columna City por NA'''
values = {'City': 'NA'}
df.fillna(value=values, inplace=True)
'''Visualizar los registros con datos nulos''
df[df.isna().any(1)]
# Out:
#   File "<ipython-input-20-576333d851ca>", line 5
#     df[df.isna().any(1)]
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
##Solucion

# %%
'''Con el comando isna() se identiica comer perdazios es lo que en'''
df[df.isna().any(1)]
# Out:
# Empty DataFrame
# Columns: [CrimeId, OriginalCrimeTypeName, OffenseDate, CallTime, CallDateTime, Disposition, Address, City, State, AgencyId, AddressType]
# Index: []

# %% [markdown]
# ## Quinto Error

# %%
'''Llamamos a la columna CrimeOid'''
set_duplicates = set(duplicates)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-522d979d10eb> in <module>()
#       1 '''Llamamos a la columna CrimeOid'''
# ----> 2 set_duplicates = set(duplicates)
#       3 df
#
# NameError: name 'duplicates' is not defined

# %% [markdown]
# ### Solucion

# %%
'''Llamamos a la columna CrimeOid para  ello debemos tener en cuenta qie 
este hecho nos permitira tener id repetidos en caso de tenerlo le aumente mas 1'''
for r in set_duplicates:
    dup = df[df['CrimeId'] == r]
    df.loc[dup.iloc[1,:].name, 'CrimeId'] = df.loc[dup.iloc[1,:].name]['CrimeId'] + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-eb800ee6cf4e> in <module>()
#       1 '''Llamamos a la columna CrimeOid para  ello debemos tener en cuenta qie
#       2 este hecho nos permitira tener id repetidos en caso de tenerlo le aumente mas 1'''
# ----> 3 for r in set_duplicates:
#       4     dup = df[df['CrimeId'] == r]
#       5     df.loc[dup.iloc[1,:].name, 'CrimeId'] = df.loc[dup.iloc[1,:].name]['CrimeId'] + 1
#
# NameError: name 'set_duplicates' is not defined

# %%
'''Veriicaciom DE SUMA DE DATO  es decir ya no existen datos repetidos en los identificadores'''
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Sexto Error

# %%
'''Luego de verificar que tenemos 2 columnas que muestran información sobre fecha y hora vamos a manejar solamente CallDateTime'''
df = df.drop(['OffenseDate'], axis=1)
df = df.drop(['CallTime'], axis=1)
df.sample(3)
# Out:
#         CrimeId OriginalCrimeTypeName         CallDateTime Disposition  \
# 2537  160930377     Suspicious Person  2016-04-02T02:42:00         GOA
# 3739  160932526       Muni Inspection  2016-04-02T16:53:00          ND
# 5554  160941731          Traffic Stop  2016-04-03T12:36:00         CIT
#
#                       Address           City State AgencyId   AddressType
# 2537          Capp St/19th St  San Francisco    CA        1  Intersection
# 3739      Kearny St/market St  San Francisco    CA        1  Intersection
# 5554  Teresita Bl/marietta Dr  San Francisco    CA        1  Intersection

# %%
''''Importacion d elibrerias y carga de datos csv hacia  formato json  respectivamente'''

import pandas as pd
df = pd.read_csv("data_act_01.csv", sep = ",")
df.to_json("test.json", orient = "records")
df.to_json
# Out:
# <bound method NDFrame.to_json of       CrimeId;OriginalCrimeTypeName;OffenseDate;CallTime;CallDateTime;Disposition;Address;City;State;AgencyId;Range;AddressType
# 0      160903280;Assault / Battery;2016-03-30T00:00:0...
# 1      160912272;Homeless Complaint;2016-03-31T00:00:...
# 2      160912590;Susp Info;2016-03-31T00:00:00;16:49;...
# 3      160912801;Report;2016-03-31T00:00:00;17:38;201...
# 4      160912811;594;2016-03-31T00:00:00;17:42;2016-0...
# ...                                                  ...
# 10046  160964210;Well Being Check;2016-04-05T00:00:00...
# 10047  160964216;Traffic Stop;2016-04-05T00:00:00;23:...
# 10048  160964227;Traffic Stop;2016-04-05T00:00:00;23:...
# 10049  160964229;Passing Call;2016-04-05T00:00:00;23:...
# 10050  160964249;Traffic Stop;2016-04-05T00:00:00;23:...
#
# [10051 rows x 1 columns]>
